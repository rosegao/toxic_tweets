# %%
import pandas as pd
import sqlite3

# %%
df = pd.read_csv("classified_tweets", encoding = "ISO-8859-1")

# %%
df = df.drop('Unnamed: 0', 1)

# %%
df.head()
# Out:
#                   date        fullname                  id  likes  replies  \
# 0  2016-01-01 23:59:59   John Sherlock  683075226960187392      1        0
# 1  2016-01-01 23:59:58      B. Justice  683075224036847616      0        0
# 2  2016-01-01 23:47:22        ABC News  683072049661620225    344      166
# 3  2016-01-01 18:04:12    Philip Lewis  682985689441525766    224        2
# 4  2016-01-01 23:59:56  Breitbart News  683075211755962368     71       59
#
#    retweets                                               text  \
# 0         0  "America is great. Trump is disgusting." #Rose...
# 1         0  @realDonaldTrump @marie7777777777 Are Trump's ...
# 2       704  Terror group Al-Shabaab releases recruitment v...
# 3       355  "Your President, Donald Trump." https://twitte...
# 4       161  Marco Rubio Campaign Donor Behind Anti-Trump S...
#
#                                         url           user       month  \
# ...

# %%
# Opens file if exists, else creates file
connex = sqlite3.connect("twitter-data.db")  
cur = connex.cursor()

# %%
df.to_sql(name='Tweets', con=connex)

# %%
con = sqlite3.connect("twitter-data.db")
df = pd.read_sql_query("SELECT text, toxic FROM Tweets WHERE toxic > 0.5 ORDER BY toxic DESC", con)

# %%
df
# Out:
#                                                  text     toxic
# 0   @that_nigga_beto ya know, I'm glad you get sat...  0.997662
# 1   Of all the girls tossing rocks at your window\...  0.997520
# 2   Enter to #Win @enjoylifefoods Baking Mixes wor...  0.992986
# 3   @DPAScottPower @TheDPA Tweet to @DPASports to ...  0.990582
# 4   Watch "Tips: Best Way To Enter The Freeway in ...  0.988801
# 5                             @Leic1s it is so canon   0.988751
# 6   My new sounds: Swiper No Swiping (Prod. By NIK...  0.979611
# 7   Wind 6,4 km/h W. Barometer 1017,85 hPa, Rising...  0.970504
# 8                        Purple Reign kinda wack tbh.  0.949569
# 9                    @arturo_boiii I still want these  0.947299
# 10                              Anyone want to skype?  0.947299
# 11  I just won #CultoftheWinds thanks to @lotsogiv...  0.946816
# 12  Wind 9,7 km/h ESE. Barometer 992,0 hPa, abfall...  0.944147
# 13  @foxsports910 Magic vs Bird, Ward vs Gatti, Jo...  0.932331
# ...
