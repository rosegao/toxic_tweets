# %%
from datetime import timedelta, date
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
filename = 'wikileaks'
df = pd.read_csv("../classified/FINAL_DATA/"+filename, encoding = "ISO-8859-1")

# %%
#filename = 'Trump'
#df1 = pd.read_csv("../classified/FINAL_DATA/"+filename, encoding = "ISO-8859-1")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'date', 'fullname', 'id', 'likes', 'replies', 'retweets',
#        'text', 'url', 'user', 'month', 'toxic', 'severe_toxic', 'obscene',
#        'threat', 'insult', 'identity_hate', 'classification', 'max_value'],
#       dtype='object')

# %%
target_columns = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']

# %% [markdown]
# ### Plotly

# %%
df['classification'] = df[target_columns].max(axis=1)
df['likes'] = df['likes'].astype(float)
df['normalized'] = df['classification']*(df['likes']+1)

#df1['classification'] = df1[target_columns].max(axis=1)
#df1['likes'] = df1['likes'].astype(float)
#df1['normalized'] = df1['classification']*(df1['likes']+1)
df.head(3)


df['day'] = [d[:10] for d in df['date']]
x = df.day
x = set(x)
x = list(x)
x = sorted(x)
x
# Out:
# ['2016-01-01',
#  '2016-01-02',
#  '2016-01-03',
#  '2016-01-04',
#  '2016-01-05',
#  '2016-01-06',
#  '2016-01-07',
#  '2016-01-08',
#  '2016-01-09',
#  '2016-01-10',
#  '2016-01-11',
#  '2016-01-12',
#  '2016-01-13',
#  '2016-01-14',
#  '2016-01-15',
#  '2016-01-16',
#  '2016-01-17',
#  '2016-01-18',
#  '2016-01-19',
#  '2016-01-20',
#  '2016-01-21',
#  '2016-01-22',
#  '2016-01-23',
#  '2016-01-24',
#  '2016-01-25',
#  '2016-01-26',
#  '2016-01-27',
#  '2016-01-28',
#  '2016-01-29',
#  '2016-01-30',
#  '2016-01-31',
#  '2016-02-01',
#  '2016-02-02',
#  '2016-02-03',
#  '2016-02-04',
#  '2016-02-05',
#  '2016-02-06',
#  '2016-02-07',
#  '2016-02-08',
#  '2016-02-09',
#  '2016-02-10',
#  '2016-02-11',
#  '2016-02-12',
#  '2016-02-13',
#  '2016-02-14',
#  '2016-02-15',
#  '2016-02-16',
#  '2016-02-17',
#  '2016-02-18',
#  '2016-02-19',
#  '2016-02-20',
#  '2016-02-21',
#  '2016-02-22',
#  '2016-02-23',
#  '2016-02-24',
#  '2016-02-25',
#  '2016-02-26',
#  '2016-02-27',
# ...

# %%
import plotly
import plotly.graph_objs as go
import plotly.plotly as py

# %%
plotly.tools.set_credentials_file(username='itlyons', api_key='PLI5e96SGllP9ELwlSTg')

# %%
prefix = ""

# %%
trace1 = go.Scatter(x=df['date'], y=df['day'], 
                    marker={'color': 'orange', 'size': "5"}, mode="markers", name='abortion')

#trace2 = go.Scatter(x=df['date'], y=df['classification'], mode="line", name='abortion')

data=go.Data([trace1])
layout=go.Layout(title="abortion", xaxis={'title':'Date'}, yaxis={'title':'Toxicity*Likes'})
figure=go.Figure(data=data,layout=layout)
url_1 = py.plot(data, filename='u1-1', sharing='public', auto_open=True)
py.iplot(figure, filename=prefix+'abortion')

url_1
# Out:
# 'https://plot.ly/~itlyons/146'

# %%
trace6 = go.Scatter(x=x, y=df['toxic'], 
                    marker={'color': 'orange', 'size': "5"}, mode="lines", name='Hillary')
                                               
data=go.Data([trace6])
layout=go.Layout(title="#Hillary", xaxis={'title':'Date'}, yaxis={'title':'Toxicity Index'})
figure=go.Figure(data=data,layout=layout)
url_6 = py.plot(data, filename='Hillary', sharing='public', auto_open=True)
py.iplot(figure, filename=prefix+'#Hillary')

url_6
# Out:
# 'https://plot.ly/~itlyons/154'

# %%
trace6 = go.Scatter(x=x, y=df['toxic'], 
                    marker={'color': 'orange', 'size': "5"}, mode="lines", name='Hillary')
                                               
data=go.Data([trace6])
layout=go.Layout(title="#Hillary", xaxis={'title':'Date'}, yaxis={'title':'Toxicity Index'})
figure=go.Figure(data=data,layout=layout)
url_6 = py.plot(data, filename='Hillary', sharing='public', auto_open=True)
py.iplot(figure, filename=prefix+'#Hillary')

url_6
# Out:
# 'https://plot.ly/~itlyons/128'

# %%
trace3 = go.Scatter(x=df['date'], y=df['classification'], marker={'color': 'purple', 'size': "5"}, 
                    mode="markers", name='releasethememo')
                                               
data=go.Data([trace3])
layout=go.Layout(title="Release the Memo", xaxis={'title':'Date'}, yaxis={'title':'Toxicity'})
figure=go.Figure(data=data,layout=layout)
url_3 = py.plot(data, filename='memo', sharing='public', auto_open=True)
py.iplot(figure, filename=prefix+'memo')

url_3
# Out:
# 'https://plot.ly/~itlyons/134'

# %%
trace1 = go.Scatter(x=df['date'], y=df['classification'], marker={'color': 'light red','size': "5"}, 
                    mode="markers", name='Hillary')

trace2 = go.Scatter(x=df1['date'], y=df1['classification'], marker={'color': 'light blue','size': "5"}, 
                    mode="markers", name='Trump')
                                               
data=go.Data([trace1,trace2])
layout=go.Layout(title="Shutdown Hashtags", xaxis={'title':'Date'}, yaxis={'title':'Toxicity Index'})
figure=go.Figure(data=data,layout=layout)
url_2 = py.plot(data, filename='second_plot', sharing='public', auto_open=True)
py.iplot(figure, filename=prefix+'SchumerShutdown vs TrumpShutdown')

url_2
# Out:
# 'https://plot.ly/~itlyons/101'

# %%
trace5 = go.Scatter(x=x, y=df['severe_toxic'], marker={'color': 'light red', 'size': "5"}, mode="lines", name='#Wikileaks')
                                               
data=go.Data([trace5])
layout=go.Layout(title="#Wikileaks", xaxis={'title':'Date'}, yaxis={'title':'Toxicity Index'})
figure=go.Figure(data=data,layout=layout)
url_5 = py.plot(data, filename='Wikileaks', sharing='public', auto_open=True)
py.iplot(figure, filename=prefix+'#Wikileaks')

url_5
# Out:
# ---------------------------------------------------------------------------
# PlotlyRequestError                        Traceback (most recent call last)
# <ipython-input-10-558b80a3eda6> in <module>()
#       4 layout=go.Layout(title="#Wikileaks", xaxis={'title':'Date'}, yaxis={'title':'Toxicity Index'})
#       5 figure=go.Figure(data=data,layout=layout)
# ----> 6 url_5 = py.plot(data, filename='Wikileaks', sharing='public', auto_open=True)
#       7 py.iplot(figure, filename=prefix+'#Wikileaks')
#       8
#
# /anaconda3/lib/python3.6/site-packages/plotly/plotly/plotly.py in plot(figure_or_data, validate, **plot_options)
#     231     data = fig.get('data', [])
#     232     plot_options['layout'] = fig.get('layout', {})
# --> 233     response = v1.clientresp(data, **plot_options)
#     234
#     235     # Check if the url needs a secret key
#
# /anaconda3/lib/python3.6/site-packages/plotly/api/v1/clientresp.py in clientresp(data, **kwargs)
#      33
# ...

# %%
def get_fileId(url):
    '''
    Derive fileID of plot from plot's url
    '''
    split = url.split("/")
    username = split[-2][1:]
    number = split[-1]
    return username + ":" + number

# %%
import plotly.dashboard_objs as dashboard
import IPython.display
from IPython.display import Image

my_dboard = dashboard.Dashboard()

# %%
box_1_fileId = get_fileId(url_1)
box_2_fileId = get_fileId(url_2)
box_3_fileId = get_fileId(url_3)
box_4_fileId = get_fileId(url_4)
box_5_fileId = get_fileId(url_5)
box_6_fileId = get_fileId(url_6)

# %%
box_1 = {
    'type': 'box',
    'boxType': 'plot',
    'fileId': box_1_fileId,
    'title': 'Toxic Plot'
}
 
box_2 = {
    'type': 'box',
    'boxType': 'plot',
    'fileId': box_2_fileId,
    'title': 'Severe Toxic Plot'
}

box_3 = {
    'type': 'box',
    'boxType': 'plot',
    'fileId': box_3_fileId,
    'title': 'Obscene Plot'
}

box_4 = {
    'type': 'box',
    'boxType': 'plot',
    'fileId': box_4_fileId,
    'title': 'Threat Plot'
}

box_5 = {
    'type': 'box',
    'boxType': 'plot',
    'fileId': box_5_fileId,
    'title': 'Insult Plot'
}

box_6 = {
    'type': 'box',
    'boxType': 'plot',
    'fileId': box_6_fileId,
    'title': 'Identity Hate Plot'
}

# %%
my_dboard.insert(box_1)
my_dboard.insert(box_4, 'below', 1)

my_dboard.insert(box_2, 'right', 1)
my_dboard.insert(box_3, 'right', 2)

my_dboard.insert(box_5, 'right', 4)
my_dboard.insert(box_6, 'right', 5)

# %%
my_dboard.get_preview()
# Out:
# <!DOCTYPE HTML>
# <html>
#   <head>
#     <style>
#       body {
#         margin: 0px;
#         padding: 0px;
#       }
#     </style>
#   </head>
#   <body>
#     <canvas id="myCanvas" width="400" height="400"></canvas>
#     <script>
#       var canvas = document.getElementById('myCanvas');
#       var context = canvas.getContext('2d');
#       <!-- Dashboard -->
#       context.beginPath();
#       context.rect(0, 0, 400, 400);
#       context.lineWidth = 2;
#       context.strokeStyle = 'black';
#       context.stroke();
#      <!-- Draw some lines in -->
#           context.beginPath();
#           context.rect(0, 200.0, 400, 1);
#           context.lineWidth = 1;
#           context.strokeStyle = 'black';
#           context.stroke();
#     <!-- Draw some lines in -->
#           context.beginPath();
#           context.rect(200.0, 0, 1, 200.0);
#           context.lineWidth = 1;
#           context.strokeStyle = 'black';
#           context.stroke();
# ...

# %%
py.dashboard_ops.upload(my_dboard, 'botsbotsbots Tweet Toxicity Dashboard')
# Out:
# 'https://plot.ly/~itlyons/117/untitled-dashboard/'

# %%
df['likes'] = df['likes'].astype(float)

# normalizing identity hate by tweet popularity
df.groupby('date')['classification'].median().plot()
