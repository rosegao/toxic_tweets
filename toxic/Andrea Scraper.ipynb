# %%
from twitterscraper import query_tweets
from datetime import timedelta, date
import pandas as pd
import csv

# %%
def scrape(query, limit_per_day, start_date, end_date):
    queries = query_tweets(query = query, 
                            limit = limit_per_day, 
                            begindate = start_date,
                            enddate = end_date, 
                            poolsize=20, lang='en')
    tweets = []
    for tweet in queries:
        tweets.append({'date': tweet.timestamp, 'text': tweet.text, 
                        'fullname': tweet.fullname, 'id': tweet.id, 
                        'likes': tweet.likes, 'replies': tweet.replies,
                        'retweets': tweet.retweets, 'url': tweet.url,
                        'user': tweet.user})
    df = pd.DataFrame(tweets)
    df['month'] = df['date'].apply(lambda x : date(x.year, x.month, 1))
    df = df.dropna()
    df = df.drop_duplicates()
    df = df[df['date'] >= start_date]
    df = df[df['date'] <= end_date]
    return df

# %%
def merge_and_clean(df_list):
    df = pd.concat(df_list)
    df = df.dropna()
    df = df.drop_duplicates()
    return df

# %%
odd_2016 = [(date(2015, 12, 31), date(2016, 2, 1)),
            (date(2016, 1, 31), date(2016, 3, 1)),
           (date(2016, 2, 29), date(2016, 4, 1)),
           (date(2016, 3, 31), date(2016, 5, 1)),
           (date(2016, 4, 30), date(2016, 6, 1)),
           (date(2016, 5, 31), date(2016, 7, 1)),
           (date(2016, 6, 30), date(2016, 8, 1)),
           (date(2016, 7, 31), date(2016, 9, 1)),
           (date(2016, 8, 31), date(2016, 10, 1)),
           (date(2016, 9, 30), date(2016, 11, 1)),
           (date(2016, 10, 31), date(2016, 12, 1)),
           (date(2016, 11, 30), date(2017, 1, 1))]

# %%
even_2016 = [(date(2016, 1, 1), date(2016, 2, 1)),
            (date(2016, 2, 1), date(2016, 3, 1)),
           (date(2016, 3, 1), date(2016, 4, 1)),
           (date(2016, 4, 1), date(2016, 5, 1)),
           (date(2016, 5, 1), date(2016, 6, 1)),
           (date(2016, 6, 1), date(2016, 7, 1)),
           (date(2016, 7, 1), date(2016, 8, 1)),
           (date(2016, 8, 1), date(2016, 9, 1)),
           (date(2016, 9, 1), date(2016, 10, 1)),
           (date(2016, 10, 1), date(2016, 11, 1)),
           (date(2016, 11, 1), date(2016, 12, 1)),
           (date(2016, 12, 1), date(2017, 1, 1))]

# %%
odd1 = odd_2016[:3]
odd2 = odd_2016[3:6]
odd3 = odd_2016[6:9]
odd4 = odd_2016[9:]
even1 = even_2016[:3]
even2 = even_2016[3:6]
even3 = even_2016[6:9]
even4 = even_2016[9:]

# %%
def go(date_range, query_term):
    df_list = []
    query = query_term
    limit_per_day = 50
    for tup in date_range:
        start_date = tup[0]
        end_date = tup[1]
        df = scrape(query, limit_per_day, start_date, end_date)
        df_list.append(df)
    bigdf = merge_and_clean(df_list)
    return bigdf

# %%
query_term = 'benghazi'
limit_per_day = 50

# %%
even3_benghazi = go(even3, query_term)

# %%
even4_benghazi = go(even4, query_term)

# %%
#min(even1_benghazi.date)

# %%
#max(even1_benghazi.date)

# %%
#min(odd4_benghazi.date)

# %%
#max(odd4_benghazi.date)

# %%
df = merge_and_clean([even3_benghazi, even4_benghazi])

# %%
#for date in df.sort_values('date').date.unique():
   #print(date)

# %%
min(df.date)
# Out:
# Timestamp('2016-07-01 19:32:39')

# %%
max(df.date)
# Out:
# Timestamp('2016-12-31 23:59:55')

# %%
df.to_csv('twitter_data/benghazi2016', mode='a', header=False)

# %%
#len(df)

# %%
df
# Out:
#                    date                       fullname                  id  \
# 1   2016-07-02 23:58:58                      John Orta  749391950575312896
# 2   2016-07-02 23:58:55             Dr Stuart Bramhall  749391938957111297
# 3   2016-07-02 23:58:38                             BP  749391865737347072
# 4   2016-07-02 23:58:36                    🇺🇸BR-549 🇺🇸  749391857805717504
# 5   2016-07-02 23:58:32                  #impeachT***P  749391839124332544
# 6   2016-07-02 23:58:20                      PapaESoCo  749391790977921025
# 7   2016-07-02 23:57:56              sean hannity buzz  749391691279265792
# 8   2016-07-02 23:57:52              Liberty & Freedom  749391674955161600
# 9   2016-07-02 23:57:52                     Covfefe007  749391670907539456
# 10  2016-07-02 23:57:45                    Sammy4Trump  749391644810555392
# 11  2016-07-02 23:57:21                           tren  749391543375654912
# 12  2016-07-02 23:57:10           TheJeffYankee@Resist  749391496961548288
# 13  2016-07-02 23:56:53                 John Gober 111  749391424257490944
# 14  2016-07-02 23:56:48            The TN Conservative  749391402694479872
# 15  2016-07-02 23:56:45             (((ChirpsMcGraw)))  749391391822721024
# 16  2016-07-02 23:56:42                   𝓝𝓪𝓿𝔂 👠𝓑𝓻𝓪𝓽 💎  749391378518605829
# 17  2016-07-02 23:56:33             osPatriot®American  749391339721072640
# 18  2016-07-02 23:56:30                     Mike Lucas  749391330116247552
# 19  2016-07-02 23:56:20                     Janet Shan  749391288496115713
# 20  2016-07-31 23:59:57                  Daniel Burdge  759901445902569477
# 21  2016-07-31 23:19:26       Laurel  🇺🇸 #BoycottNRA 🚫  759891249557938176
# 22  2016-07-31 23:59:45                      Boolouise  759901395415736320
# 23  2016-07-31 23:59:43                     The Editor  759901385546534912
# 24  2016-07-31 23:59:34                    Della Pearl  759901348301115393
# 25  2016-07-31 23:59:26           Deplorable ImaCracka  759901316231507968
# 26  2016-07-31 23:59:16                     The Editor  759901275173494784
# 27  2016-07-31 23:59:16                     Gina Maria  759901274250764288
# 28  2016-07-31 23:59:09                  Laura Marklin  759901245859561473
# 29  2016-07-31 23:59:06              Peter Plenkiewicz  759901231590637568
# 30  2016-07-31 23:58:52                         DAMGÅR  759901173570793472
# ..                  ...                            ...                 ...
# 276 2016-12-31 23:46:08            Sophie 🌹  ❤️ 🇺🇸 🚔 🙏  815343311171059712
# 277 2016-12-31 23:45:35           Daniel John Sobieski  815343175296434176
# 278 2016-12-31 23:45:27                  Glen Buhlmann  815343138042617856
# 279 2016-12-31 23:43:57                Deplorable Mark  815342762719584256
# 280 2016-12-31 23:43:32            Michael Lightwalker  815342656427593728
# 281 2016-12-31 23:42:40             RepealReplaceGOP18  815342440467099652
# 282 2016-12-31 23:41:55                  Hillary Sweig  815342251689779200
# 283 2016-12-31 23:41:30             Michael Macpherson  815342144097398784
# 284 2016-12-31 23:41:12             TINAs CATHOLIC 🚂 💨  815342070768410625
# 285 2016-12-31 23:41:04                Deplorable Mark  815342036148781060
# 286 2016-12-04 23:58:31             Nasty Cynical Turd  805561957520547841
# 287 2016-12-04 23:58:27           Daniel John Sobieski  805561938725859328
# 288 2016-12-04 23:57:58                Hillary Clinton  805561815912579072
# 289 2016-12-04 23:57:53                 Michael Najvar  805561795612020736
# 290 2016-12-04 23:57:01                    Elvis Nixon  805561579987234816
# 291 2016-12-04 23:56:52                  Samanda Purse  805561538996305920
# 292 2016-12-04 23:56:44                    RightAsRain  805561508340105216
# 293 2016-12-04 23:55:49                  aaron centeno  805561275010793472
# 294 2016-12-04 23:55:48                     MandoMando  805561270191685632
# 295 2016-12-04 23:55:22                        ✭Becca✭  805561164251983872
# 296 2016-12-04 23:53:51                      Alex °Ξ☻Ξ  805560780494086144
# 297 2016-12-04 23:53:24                           Mike  805560667235319808
# 298 2016-12-04 23:53:18                    MondoMike65  805560644648910848
# 299 2016-12-04 23:51:17             Old Hippie Charlie  805560136257466368
# 300 2016-12-04 23:49:35                        Gumlegs  805559706215469060
# 301 2016-12-04 23:48:43             Holly of Hollywood  805559488098881536
# 302 2016-12-04 23:44:49                    Happy Girl.  805558509261582340
# 303 2016-12-04 23:42:36             DEPLORABLE CLAUDIA  805557951947833345
# 304 2016-12-04 23:42:02  BabySpittle  🇺🇸 #BoycottNRA 🚫  805557807491649536
# 305 2016-12-04 23:41:48                    gmarie  🎼 🌊  805557750726070277
#
#     likes replies retweets                                               text  \
# 1       0       0        0  Benghazi chair Gowdy in GOP address: “We now k...
# 2       0       0        0  Benghazi Scandal Report--Hillary Was Part of M...
# 3       0       0        0  Here's the KEY MOMENT in Benghazi hearings - R...
# 4       0       0        0  Do you have your #BenghaziReport yet?\nYou can...
# 5       1       0        0  So clear of Benghazi, FBI finds no wrong doing...
# 6       0       1        0  Michael Savage: 'Trey Gowdy Should Be Impeache...
# 7       0       0        1  Sean Hannity Gets Humiliated After Pushing Abs...
# 8       0       0        0  Bloomberg Radio calls Benghazi a "Dead Issue",...
# 9       0       0        0  TRUMP CAN NEVER WIN ITS ALREADY RIGGED KILLARY...
# 10      1       0        1  I don't know how Obama finds these creeps.Susa...
# 11      0       0        1  Benghazi casts doubt on Clinton's fitness for ...
# 12     13       0       10  The whole thing was! Toss in Benghazi and you ...
# 13      0       0        0  Widow Of Benghazi Victim: No One Has “The Righ...
# 14      0       0        0  The Benghazi report was released, demonstratin...
# 15      0       0        0  After the GOP just wasted 2 years and 7 mill i...
# 16      3       2        2  Left said #Benghazi is nothing but a #WitchHun...
# 17      0       0        0  ☭«BLOCKED, due 2 ur overwhelming display of ig...
# 18      0       0        0  Benghazi report shows Hilary & Obama more conc...
# 19      0       0        0  Grilled? These right wingnuts have such an ima...
# 20      0       0        0  how about the men at Benghazi dying under Hill...
# 21    118       7      100  Hillary Clinton Storms Fox News And Blows Up T...
# 22      0       0        1  Why didn't the MSM have a fit when Hillary sto...
# 23      0       0        0  Clinton responds to criticism over Benghazi, p...
# 24      0       0        1  Worst candidate ever. See #HillarysAmerica to ...
# 25      1       0        2  OMG #CrookedHillary is such a LIAR! She's stil...
# 26      0       0        0  Chris Wallace grills Clinton on Benghazi, poli...
# 27      0       0        0  The difference btwn Trump and Obama/Hillary is...
# 28      0       0        0  Did you write an article that @HillaryClinton ...
# 29      0       0        0  Clinton&#8217;s Claim About Benghazi Sparks In...
# 30      0       1        0  also I didn't complain once when it was the pa...
# ..    ...     ...      ...                                                ...
# 276     0       0        0  libS support & protect WhGenocide solictg but ...
# 277     1       0        0  (IBD) Hillary Clinton Email Gaps Hide 'Pay 4 P...
# 278     0       0        0  Have @LOLGOP finished investigating #Benghazi ...
# 279     0       2        0                        you're ignorance is showing
# 280     0       0        0  Makes me think of a movie I watched last night...
# 281    12       3        8  Maybe there would be money for Flint if you fu...
# 282     0       0        0  This a real Benghazi. Wake up America. DT owns...
# 283     0       0        0  Never forget that BOTH PARTIES have players in...
# 284     1       0        0  MT @daeshhun: May They Be Haunted Forever \nBy...
# 285     1       0        0  Clinton Was First Official To Blame Benghazi A...
# 286     1       1        1  No they won't. Still blame us #GOP can't own t...
# 287     1       0        6  Obama's Rasputin Jarrett @vj44 Gave #Benghazi ...
# 288     0       0        0  I steal money from dnc  --  i believe that ver...
# 289     0       0        0  #pjnet remember, the H is silent in BengHazi h...
# 290     0       0        0  Obama lied about a video"slander" of Muhammad ...
# 291     0       0        0  I just bought a cool new iPad Benghazi has not...
# 292     0       0        0  @LindaAndolina1 @DrJillStein @FoxNews @CNN Rep...
# 293     0       7        1  @Rosie @ThisWeekABC @GStephanopoulos So did Hi...
# 294     0       0        0  @GeraldoRivera Keep defending criminals https:...
# 295     1       0        0  And, whatever it was- his supporters would sti...
# 296     0       0        0  Same way Hollywood promoted Indy film disgraci...
# 297     0       0        0  "COULD HAVE"?? Could've been Illegal emails, B...
# 298     0       0        0  AWSOME, we have our very own Benghazi now? How...
# 299     1       0        0  After #Benghazi, incompetent #Trump pick #Mike...
# 300     0       0        0  If this report is true, @NBCInvestigates shoul...
# 301     0       0        0  Pamela Geller, American Thinker Book Review:<b...
# 302     0      10        0                  REALLY? Have you forgot Benghazi?
# 303     0       0        0  I think the reason might be simple:  HILLARY C...
# 304     1       0        0  After Benghazi, incompetent Trump pick Mike Fl...
# 305     0       0        0  After Benghazi, incompetent Trump pick Mike Fl...
#
#                                             url             user       month
# 1          /JohnOrta4/status/749391950575312896        JohnOrta4  2016-07-01
# 2     /stuartbramhall/status/749391938957111297   stuartbramhall  2016-07-01
# 3             /b2646p/status/749391865737347072           b2646p  2016-07-01
# 4      /USA___Forever/status/749391857805717504    USA___Forever  2016-07-01
# 5           /patysq73/status/749391839124332544         patysq73  2016-07-01
# 6          /PapaESoCo/status/749391790977921025        PapaESoCo  2016-07-01
# 7         /cinnews365/status/749391691279265792       cinnews365  2016-07-01
# 8              /Oahts/status/749391674955161600            Oahts  2016-07-01
# 9          /Nancy007f/status/749391670907539456        Nancy007f  2016-07-01
# 10         /tomsam974/status/749391644810555392        tomsam974  2016-07-01
# 11        /300thework/status/749391543375654912       300thework  2016-07-01
# 12     /ibelieveinusa/status/749391496961548288    ibelieveinusa  2016-07-01
# 13      /John12590973/status/749391424257490944     John12590973  2016-07-01
# 14       /TennConserv/status/749391402694479872      TennConserv  2016-07-01
# 15   /PonyboyMichaelC/status/749391391822721024  PonyboyMichaelC  2016-07-01
# 16       /RavenHUWolf/status/749391378518605829      RavenHUWolf  2016-07-01
# 17         /osPatriot/status/749391339721072640        osPatriot  2016-07-01
# 18       /semigator07/status/749391330116247552      semigator07  2016-07-01
# 19       /hinterlandg/status/749391288496115713      hinterlandg  2016-07-01
# 20     /daniel_burdge/status/759901445902569477    daniel_burdge  2016-07-01
# 21   /laureldavilacpa/status/759891249557938176  laureldavilacpa  2016-07-01
# 22         /boolouise/status/759901395415736320        boolouise  2016-07-01
# 23    /TheDailyDigest/status/759901385546534912   TheDailyDigest  2016-07-01
# 24        /Dellapearl/status/759901348301115393       Dellapearl  2016-07-01
# 25   /JanetOstrowski1/status/759901316231507968  JanetOstrowski1  2016-07-01
# 26    /TheDailyDigest/status/759901275173494784   TheDailyDigest  2016-07-01
# 27       /Ginabeans22/status/759901274250764288      Ginabeans22  2016-07-01
# 28      /LauraMarklin/status/759901245859561473     LauraMarklin  2016-07-01
# 29          /pplenkie/status/759901231590637568         pplenkie  2016-07-01
# 30      /NorthlandTim/status/759901173570793472     NorthlandTim  2016-07-01
# ..                                          ...              ...         ...
# 276    /bellas_Sophie/status/815343311171059712    bellas_Sophie  2016-12-01
# 277   /gerfingerpoken/status/815343175296434176   gerfingerpoken  2016-12-01
# 278        /GlenBikes/status/815343138042617856        GlenBikes  2016-12-01
# 279    /mark_selby723/status/815342762719584256    mark_selby723  2016-12-01
# 280  /MikeLightwalker/status/815342656427593728  MikeLightwalker  2016-12-01
# 281          /Drey527/status/815342440467099652          Drey527  2016-12-01
# 282           /hsweig/status/815342251689779200           hsweig  2016-12-01
# 283    /TerranomaLead/status/815342144097398784    TerranomaLead  2016-12-01
# 284   /knowladgeispwr/status/815342070768410625   knowladgeispwr  2016-12-01
# 285    /mark_selby723/status/815342036148781060    mark_selby723  2016-12-01
# 286     /Cynical_turd/status/805561957520547841     Cynical_turd  2016-12-01
# 287   /gerfingerpoken/status/805561938725859328   gerfingerpoken  2016-12-01
# 288   /HILLARYCL1NT0N/status/805561815912579072   HILLARYCL1NT0N  2016-12-01
# 289    /chickenman246/status/805561795612020736    chickenman246  2016-12-01
# 290      /ElvisNixon7/status/805561579987234816      ElvisNixon7  2016-12-01
# 291       /samanda666/status/805561538996305920       samanda666  2016-12-01
# 292     /RightAsRain7/status/805561508340105216     RightAsRain7  2016-12-01
# 293          /roncent/status/805561275010793472          roncent  2016-12-01
# 294         /Malangas/status/805561270191685632         Malangas  2016-12-01
# 295      /dix_iechick/status/805561164251983872      dix_iechick  2016-12-01
# 296   /AntonioReyX360/status/805560780494086144   AntonioReyX360  2016-12-01
# 297      /TheACTUAL40/status/805560667235319808      TheACTUAL40  2016-12-01
# 298      /mondomike65/status/805560644648910848      mondomike65  2016-12-01
# 299        /cwpontwit/status/805560136257466368        cwpontwit  2016-12-01
# 300          /Gumlegs/status/805559706215469060          Gumlegs  2016-12-01
# 301  /WhollyAmericana/status/805559488098881536  WhollyAmericana  2016-12-01
# 302      /boysnana372/status/805558509261582340      boysnana372  2016-12-01
# 303  /claudiascompan1/status/805557951947833345  claudiascompan1  2016-12-01
# 304      /babyspittle/status/805557807491649536      babyspittle  2016-12-01
# 305         /gmarie55/status/805557750726070277         gmarie55  2016-12-01
#
# [1817 rows x 10 columns]

# %%
df['text'].head()[1]
# Out:
# 'Benghazi chair Gowdy in GOP address: “We now know the full story” http://www.mcclatchydc.com/news/politics-government/congress/article87352957.html\xa0…'

# %%
len(df)
# Out:
# 1817
