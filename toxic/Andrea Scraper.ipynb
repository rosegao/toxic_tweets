# %%
from twitterscraper import query_tweets
from datetime import timedelta, date
import pandas as pd
import csv

# %%
def scrape(query, limit_per_day, start_date, end_date):
    queries = query_tweets(query = query, 
                            limit = limit_per_day, 
                            begindate = start_date,
                            enddate = end_date, 
                            poolsize=20, lang='en')
    tweets = []
    for tweet in queries:
        tweets.append({'date': tweet.timestamp, 'text': tweet.text, 
                        'fullname': tweet.fullname, 'id': tweet.id, 
                        'likes': tweet.likes, 'replies': tweet.replies,
                        'retweets': tweet.retweets, 'url': tweet.url,
                        'user': tweet.user})
    df = pd.DataFrame(tweets)
    df['month'] = df['date'].apply(lambda x : date(x.year, x.month, 1))
    df = df.dropna()
    df = df.drop_duplicates()
    df = df[df['date'] >= start_date]
    df = df[df['date'] <= end_date]
    return df

# %%
def merge_and_clean(df_list):
    df = pd.concat(df_list)
    df = df.dropna()
    df = df.drop_duplicates()
    return df

# %%
odd_2016 = [(date(2015, 12, 31), date(2016, 2, 1)),
            (date(2016, 1, 31), date(2016, 3, 1)),
           (date(2016, 2, 29), date(2016, 4, 1)),
           (date(2016, 3, 31), date(2016, 5, 1)),
           (date(2016, 4, 30), date(2016, 6, 1)),
           (date(2016, 5, 31), date(2016, 7, 1)),
           (date(2016, 6, 30), date(2016, 8, 1)),
           (date(2016, 7, 31), date(2016, 9, 1)),
           (date(2016, 8, 31), date(2016, 10, 1)),
           (date(2016, 9, 30), date(2016, 11, 1)),
           (date(2016, 10, 31), date(2016, 12, 1)),
           (date(2016, 11, 30), date(2017, 1, 1))]

# %%
even_2016 = [(date(2016, 1, 1), date(2016, 2, 1)),
            (date(2016, 2, 1), date(2016, 3, 1)),
           (date(2016, 3, 1), date(2016, 4, 1)),
           (date(2016, 4, 1), date(2016, 5, 1)),
           (date(2016, 5, 1), date(2016, 6, 1)),
           (date(2016, 6, 1), date(2016, 7, 1)),
           (date(2016, 7, 1), date(2016, 8, 1)),
           (date(2016, 8, 1), date(2016, 9, 1)),
           (date(2016, 9, 1), date(2016, 10, 1)),
           (date(2016, 10, 1), date(2016, 11, 1)),
           (date(2016, 11, 1), date(2016, 12, 1)),
           (date(2016, 12, 1), date(2017, 1, 1))]

# %%
odd1 = odd_2016[:3]
odd2 = odd_2016[3:6]
odd3 = odd_2016[6:9]
odd4 = odd_2016[9:]
even1 = even_2016[:3]
even2 = even_2016[3:6]
even3 = even_2016[6:9]
even4 = even_2016[9:]

# %%
def go(date_range, query_term):
    df_list = []
    query = query_term
    limit_per_day = 50
    for tup in date_range:
        start_date = tup[0]
        end_date = tup[1]
        df = scrape(query, limit_per_day, start_date, end_date)
        df_list.append(df)
    bigdf = merge_and_clean(df_list)
    return bigdf

# %%
query_term = 'electoral college'
limit_per_day = 20

# %%
even3 = go(even3, query_term)

# %%
even4 = go(even4, query_term)

# %%
df = merge_and_clean([even3, even4])

# %%
#for date in df.sort_values('date').date.unique():
   #print(date)

# %%
min(df.date)
# Out:
# Timestamp('2016-07-02 22:03:19')

# %%
max(df.date)
# Out:
# Timestamp('2016-12-31 23:59:49')

# %%
df.to_csv('twitter_data/andrea_scraped/electoralcollege2016', mode='a', header=False)

# %%
#len(df)

# %%
df
# Out:
#                    date                          fullname                  id  \
# 0   2016-07-22 23:58:57                  Markham Robinson  756639703625936896
# 1   2016-07-22 23:57:55                aka David Dennison  756639444376190977
# 2   2016-07-22 23:55:10                  Markham Robinson  756638750621339648
# 3   2016-07-22 23:55:05                        Axman27  🐉  756638731264819201
# 4   2016-07-22 23:53:56                        butterball  756638440691605504
# 5   2016-07-22 23:52:54                  Markham Robinson  756638180011421696
# 6   2016-07-22 23:52:22                    Daniel Parsons  756638047505149952
# 7   2016-07-22 23:48:52                    Sarah Reynolds  756637163316387840
# 8   2016-07-22 23:45:07                   James S Russell  756636223368630272
# 9   2016-07-22 23:44:35              Meshuggenah Nitabach  756636085707571200
# 10  2016-07-22 23:30:08               Joseph L. Rosenberg  756632450831360000
# 11  2016-07-22 23:29:06                     Carol Leonard  756632192688787459
# 12  2016-07-22 23:26:30                        Joey Gindi  756631538385772544
# 13  2016-07-22 23:25:29                           Garrett  756631281144778752
# 14  2016-07-22 23:23:31                            He-Man  756630786934185987
# 15  2016-07-22 23:21:25           Rebecca  ; and Molly  🐕  756630258724532224
# 16  2016-07-22 23:21:23                     Trina Justice  756630249736179712
# 17  2016-07-22 23:19:53                   no one you know  756629871426572288
# 18  2016-07-22 23:18:23                    Hugo Saenz Jr.  756629492785872897
# 19  2016-07-22 23:16:54                         Ben Gunby  756629121430654977
# 20  2016-07-20 23:56:51                 Christopher Gomez  755914397575475200
# 21  2016-07-20 23:55:35                         Gabrielle  755914081316573184
# 22  2016-07-20 23:55:35                      David Wright  755914078850277376
# 23  2016-07-20 23:53:01                       JAYGODMEDIA  755913433036558336
# 24  2016-07-20 23:52:23                            Krunox  755913275058126853
# 25  2016-07-20 23:49:03                       Jeff Fortin  755912435454779392
# 26  2016-07-20 23:40:16                               Dad  755910227028049921
# 27  2016-07-20 23:38:25                      Lord Skibabs  755909759950204930
# 28  2016-07-20 23:38:25               Ogrilly The Dreamer  755909759048425472
# 29  2016-07-20 23:38:24                           Maryees  755909753860009984
# ..                  ...                               ...                 ...
# 290 2016-12-31 23:54:22                              Wulf  815345385019506689
# 291 2016-12-31 23:53:13                    CrystalBallOps  815345092890267648
# 292 2016-12-31 23:52:45                           Mr Nemo  815344975282049024
# 293 2016-12-31 23:51:42                              Aran  815344710718001152
# 294 2016-12-31 23:51:33                     Richard Creed  815344676106539009
# 295 2016-12-31 23:49:29                             Maxim  815344154079207424
# 296 2016-12-31 23:49:26                    HumanismRising  815344142536572928
# 297 2016-12-31 23:49:24                🍔 Derp State Chris  815344134034771968
# 298 2016-12-31 23:49:12                      Drjoanlovell  815344084495646720
# 299 2016-12-31 23:48:44  Congressional Medal of Respondix  815343965624860672
# 300 2016-12-14 23:59:56                     George Harris  809186192172453888
# 301 2016-12-14 23:45:34               Once A Great Nation  809182574308274177
# 302 2016-12-14 21:18:11                       Lori Hendry  809145483386060801
# 303 2016-12-14 23:44:50                   Keith Olbermann  809182390371418114
# 304 2016-12-14 23:43:56                          WayneEdH  809182165317615616
# 305 2016-12-14 23:59:51                      ignatzfattis  809186171829960704
# 306 2016-12-14 23:59:49                        Rose  Hill  809186162682183681
# 307 2016-12-14 23:59:42                    chris marshall  809186131120156672
# 308 2016-12-14 23:59:38                       Chris Colon  809186114984701952
# 309 2016-12-14 23:59:37                      Joanna Busch  809186111557869568
# 310 2016-12-14 23:59:37                      chris berdos  809186109565583360
# 311 2016-12-14 23:59:35                  Dorothy Li Calzi  809186101340602369
# 312 2016-12-14 23:59:33                        sisterhood  809186092847104000
# 313 2016-12-14 23:59:30                        lori white  809186081862254593
# 314 2016-12-14 23:59:17                      Leslie Smith  809186028221104129
# 315 2016-12-14 23:59:17                 Democracy is Dead  809186027512492032
# 316 2016-12-14 23:59:14                      Jess Sumpter  809186015390924809
# 317 2016-12-14 23:59:12                 Fanta-C Creations  809186004682870784
# 318 2016-12-14 23:59:06                Angela K. Crandall  809185979575762945
# 319 2016-12-14 23:59:01                        LeoKapakos  809185961515057152
#
#     likes replies retweets                                               text  \
# 0       3       0        1  。@jslagra The real candidates in Presidential ...
# 1       0       0        0  If Kaine is picked purely because of Virginia ...
# 2       5       1        5  If the AIP & the CA Reps take 5 & 50 Electoral...
# 3       0       0        0  no...its the electoral college that decides a ...
# 4       0       1        0  haha silly goose of course i know what the ele...
# 5       5       0        2  The AIP can by agreement with the CA Republica...
# 6       3       0        0  My fav part of The Purge: Election Year is tha...
# 7       2       1        2  Google "electoral college," learn math, and th...
# 8       0       0        0  Clinton’s Lead in Electoral College is Falling...
# 9       0       1        0  Totally agree with the "let's do this rhetoric...
# 10      0       0        0             will the electoral college do its job.
# 11      1       0        0  Yes she will get rid of the electoral college ...
# 12      1       1        0  The General Election electoral college has not...
# 13      0       1        0  yeah more people in the country. That means no...
# 14      0       0        0  well many people didn't vote because they don'...
# 15      1       0        0  Well, to be fairish, that probably depends on ...
# 16      0       0        0  ELECTORAL COLLEGE: How is this possible???? Ob...
# 17      0       1        0  I don't follow?  The Electoral College makes s...
# 18      0       0        0  I doubt Trump wins the electoral college. That...
# 19      0       1        0                    The electoral college disagrees
# 20      0       0        0  A Bootstrap Simulation on Electoral College vo...
# 21      0       0        0  When you're watching @Jeopardy and no one know...
# 22      0       0        0  Road to 270: CNN's new electoral college map h...
# 23      0       0        0  Road to 270: CNN's new electoral college map h...
# 24      0       0        0  Road to 270: CNN's new electoral college map -...
# 25      0       0        0  Road to 270: CNN's new electoral college map  ...
# 26      3       0        0  You must not know how the electoral college wo...
# 27      0       0        0  Clinton leads electoral college map: The recen...
# 28      0       0        0  Clinton leads electoral college map http://dlv...
# 29      0       0        0  Clinton leads electoral college map http://dlv...
# ..    ...     ...      ...                                                ...
# 290     1       0        0  The electoral college elected that guy. The ma...
# 291     1       1        0  unfortunately our Electoral College 'circuit b...
# 292     1       0        0  The Electoral College (EC) system enables 538 ...
# 293     0       1        0  (And if US democracy does come out of this int...
# 294     0       2        0  be nice if you remembered the constitution & h...
# 295     0       0        0  Remember the good old days when you were cryin...
# 296     0       0        0  the #ElectoralCollege weakens the #vote of min...
# 297     1       0        0  .@realDonaldTrump You lost the popular electio...
# 298     0       0        0  # minority president.  Congrats on electoral c...
# 299     0       1        0  or when you try to get the popular vote total ...
# 300     0       0        0  .@AmmoniteInk It would have to be from the top...
# 301    23       0       16  Don't waste time telling us -- get to the 538 ...
# 302   493      89      583  White House and Hillary directly tied to #Elec...
# 303  1096      66      611  NEW: As 20+ Trump Electors hint at vote switch...
# 304   139      12      157  And the GOP/FBI/Russian Band Played On!!\nElec...
# 305     0       0        0  Electoral College Electors Have Written a Lett...
# 306     2       0        1  Why theres an electoral college Alexander #Ham...
# 307     1       0        1  Read Chris Miller's letter to members of the E...
# 308     0       0        0  A logical argument for the electoral college t...
# 309     0       0        0  Bravo! I hope the Electoral College delegates ...
# 310     0       0        0  one down, 36 to go\n#InformTheElectors\n#Elect...
# 311     0       0        0  Electoral College Revolt Growing Into 'Powerfu...
# 312     0       0        0  @GOP @TheDemocrats @ElectoralCollge @DOJ @POTU...
# 313     0       0        1  U.S. officials say Putin helped direct the use...
# 314     1       0        1  #russianhack #russiagate #BREAKING #ElectoralC...
# 315     0       1        0  Electoral College should vote the way they wan...
# 316     1       0        1  ELECTORAL COLLEGE, YOU ARE CONSTITUTIONALLY BO...
# 317     0       0        0  Hillary & Obama's PR Firm is Running the Elect...
# 318     0       0        1  @POTUS: Declassify evidence of Russian interfe...
# 319     0       0        0  @Reince Priebus & Trump plan on having the mos...
#
#                                             url             user       month
# 0           /BraveLad/status/756639703625936896         BraveLad  2016-07-01
# 1             /rowast/status/756639444376190977           rowast  2016-07-01
# 2           /BraveLad/status/756638750621339648         BraveLad  2016-07-01
# 3           /axman_27/status/756638731264819201         axman_27  2016-07-01
# 4        /teamBasilio/status/756638440691605504      teamBasilio  2016-07-01
# 5           /BraveLad/status/756638180011421696         BraveLad  2016-07-01
# 6      /dandanparsons/status/756638047505149952    dandanparsons  2016-07-01
# 7    /Sarah__Reynolds/status/756637163316387840  Sarah__Reynolds  2016-07-01
# 8       /jamesswriter/status/756636223368630272     jamesswriter  2016-07-01
# 9          /mnitabach/status/756636085707571200        mnitabach  2016-07-01
# 10            /cpajoe/status/756632450831360000           cpajoe  2016-07-01
# 11   /laughingcat2016/status/756632192688787459  laughingcat2016  2016-07-01
# 12          /Vatredox/status/756631538385772544         Vatredox  2016-07-01
# 13     /GarrettRooker/status/756631281144778752    GarrettRooker  2016-07-01
# 14           /Tim1003/status/756630786934185987          Tim1003  2016-07-01
# 15         /edutinker/status/756630258724532224        edutinker  2016-07-01
# 16     /Trina4justice/status/756630249736179712    Trina4justice  2016-07-01
# 17   /Nobody_special1/status/756629871426572288  Nobody_special1  2016-07-01
# 18     /TheMovement94/status/756629492785872897    TheMovement94  2016-07-01
# 19        /gumby61184/status/756629121430654977       gumby61184  2016-07-01
# 20   /chris_n_vinegar/status/755914397575475200  chris_n_vinegar  2016-07-01
# 21          /gfstarr1/status/755914081316573184         gfstarr1  2016-07-01
# 22   /DavidWright_CNN/status/755914078850277376  DavidWright_CNN  2016-07-01
# 23            /JAYGOD/status/755913433036558336           JAYGOD  2016-07-01
# 24         /krunox123/status/755913275058126853        krunox123  2016-07-01
# 25   /clickchoiceauto/status/755912435454779392  clickchoiceauto  2016-07-01
# 26   /DishesInThaSink/status/755910227028049921  DishesInThaSink  2016-07-01
# 27           /Skibabs/status/755909759950204930          Skibabs  2016-07-01
# 28        /I_am_OgijO/status/755909759048425472       I_am_OgijO  2016-07-01
# 29       /Merryiyanda/status/755909753860009984      Merryiyanda  2016-07-01
# ..                                          ...              ...         ...
# 290    /Accelerwraith/status/815345385019506689    Accelerwraith  2016-12-01
# 291          /feefer2/status/815345092890267648          feefer2  2016-12-01
# 292       /MrNemo1957/status/815344975282049024       MrNemo1957  2016-12-01
# 293        /aranbriar/status/815344710718001152        aranbriar  2016-12-01
# 294         /drrcreed/status/815344676106539009         drrcreed  2016-12-01
# 295     /bedroomindie/status/815344154079207424     bedroomindie  2016-12-01
# 296  /LetHumanismRing/status/815344142536572928  LetHumanismRing  2016-12-01
# 297      /closerchris/status/815344134034771968      closerchris  2016-12-01
# 298  /ellenlovellmayb/status/815344084495646720  ellenlovellmayb  2016-12-01
# 299        /respondix/status/815343965624860672        respondix  2016-12-01
# 300     /BullCityFats/status/809186192172453888     BullCityFats  2016-12-01
# 301      /lightheart1/status/809182574308274177      lightheart1  2016-12-01
# 302        /Lrihendry/status/809145483386060801        Lrihendry  2016-12-01
# 303   /KeithOlbermann/status/809182390371418114   KeithOlbermann  2016-12-01
# 304         /WayneEdH/status/809182165317615616         WayneEdH  2016-12-01
# 305     /ignatzfattis/status/809186171829960704     ignatzfattis  2016-12-01
# 306     /ForgotBeauty/status/809186162682183681     ForgotBeauty  2016-12-01
# 307     /dbcdthumper5/status/809186131120156672     dbcdthumper5  2016-12-01
# 308            /xlnyc/status/809186114984701952            xlnyc  2016-12-01
# 309   /naturegirl1980/status/809186111557869568   naturegirl1980  2016-12-01
# 310    /jazzynaturist/status/809186109565583360    jazzynaturist  2016-12-01
# 311       /Dorofcalif/status/809186101340602369       Dorofcalif  2016-12-01
# 312      /vickieclayb/status/809186092847104000      vickieclayb  2016-12-01
# 313      /LORIWHITE94/status/809186081862254593      LORIWHITE94  2016-12-01
# 314      /lplatosmith/status/809186028221104129      lplatosmith  2016-12-01
# 315   /Libertycries17/status/809186027512492032   Libertycries17  2016-12-01
# 316       /jessayin2U/status/809186015390924809       jessayin2U  2016-12-01
# 317     /flsunsweetie/status/809186004682870784     flsunsweetie  2016-12-01
# 318      /Hopemadonna/status/809185979575762945      Hopemadonna  2016-12-01
# 319     /LeoKapakosNY/status/809185961515057152     LeoKapakosNY  2016-12-01
#
# [1848 rows x 10 columns]

# %%
df['text'].head()[4]
# Out:
# "haha silly goose of course i know what the electoral college is but that's not what I'm talking about. I'm done haha"

# %%
len(df)
# Out:
# 1848
